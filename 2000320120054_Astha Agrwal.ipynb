# %% [markdown]
# Using SVM( Support Vector Machine)

# %%
#Collecting Dataset
import numpy as np
from sklearn.datasets import load_digits

# %%
#load & Summarize Dataset
dataset = load_digits()

# %%
print(dataset.data)
print(dataset.target)
print(dataset.data.shape)
print(dataset.images.shape)
dataimageLength = len(dataset.images)
print(dataimageLength)
# Out:
# [[ 0.  0.  5. ...  0.  0.  0.]
#  [ 0.  0.  0. ... 10.  0.  0.]
#  [ 0.  0.  0. ... 16.  9.  0.]
#  ...
#  [ 0.  0.  1. ...  6.  0.  0.]
#  [ 0.  0.  2. ... 12.  0.  0.]
#  [ 0.  0. 10. ... 12.  1.  0.]]
# [0 1 2 ... 8 9 8]
# (1797, 64)
# (1797, 8, 8)
# 1797

# %%
#Visualize the data
n=4
import matplotlib.pyplot as plt
plt.gray()
plt.matshow(dataset.images[n])
plt.show()
dataset.images[n]
# Out:
# array([[ 0.,  0.,  0.,  1., 11.,  0.,  0.,  0.],
#        [ 0.,  0.,  0.,  7.,  8.,  0.,  0.,  0.],
#        [ 0.,  0.,  1., 13.,  6.,  2.,  2.,  0.],
#        [ 0.,  0.,  7., 15.,  0.,  9.,  8.,  0.],
#        [ 0.,  5., 16., 10.,  0., 16.,  6.,  0.],
#        [ 0.,  4., 15., 16., 13., 16.,  1.,  0.],
#        [ 0.,  0.,  0.,  3., 15., 10.,  0.,  0.],
#        [ 0.,  0.,  0.,  2., 16.,  4.,  0.,  0.]])

# %%
#Segregating dataset into X&Y (Input /Output)
x=dataset.images.reshape((dataimageLength, -1))
x
# Out:
# array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#        [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#        [ 0.,  0., 10., ..., 12.,  1.,  0.]])

# %%
y=dataset.target
y
# Out:
# array([0, 1, 2, ..., 8, 9, 8])

# %%
#Splitting Dataset to train and test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x,y,test_size=0.25, random_state=0)
print(x_train.shape)
print(x_test.shape)
# Out:
# (1347, 64)
# (450, 64)

# %%
#Applying Algorithm- SVN Classifier
from sklearn import svm
model=svm.SVC(kernel='linear')
model.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
# Training Model for preprocessed dataset
n=5
result=model.predict(datset.images[n].reshape((1,-1)))
plt.imshow(dataset.images[n], cmap=plt.cm.gray_r, interpolation='nearest')
print(result)
print("\n")
print("off")
plt.title("%i"%result)
plt.show()
# Out:
# [9]
#
#
# off

# %%
# Evaluate/ Validation
y_pred=model.predict(x_test)
print(np.concatenate((y_pred.reshape(len(y_pred),1),y_test.reshape(len(y_test),1)),1))
# Out:
# [[2 2]
#  [8 8]
#  [2 2]
#  [6 6]
#  [6 6]
#  [7 7]
#  [1 1]
#  [9 9]
#  [8 8]
#  [5 5]
#  [2 2]
#  [8 8]
#  [6 6]
#  [6 6]
#  [6 6]
#  [6 6]
#  [1 1]
#  [0 0]
#  [5 5]
#  [8 8]
#  [8 8]
#  [7 7]
#  [8 8]
#  [4 4]
#  [7 7]
#  [5 5]
#  [4 4]
#  [9 9]
#  [2 2]
#  [9 9]
#  [4 4]
#  [7 7]
#  [6 6]
#  [8 8]
#  [9 9]
#  [4 4]
#  [3 3]
#  [1 1]
#  [0 0]
#  [1 1]
#  [8 8]
#  [6 6]
#  [7 7]
#  [7 7]
#  [1 1]
#  [0 0]
#  [7 7]
#  [6 6]
#  [2 2]
#  [1 1]
#  [9 9]
#  [6 6]
#  [7 7]
#  [9 9]
#  [0 0]
#  [0 0]
#  [5 5]
#  [1 1]
#  [6 6]
#  [3 3]
#  [0 0]
#  [2 2]
#  [3 3]
#  [4 4]
#  [1 1]
#  [9 9]
#  [2 2]
#  [6 6]
#  [9 9]
#  [1 1]
#  [8 8]
#  [3 3]
#  [5 5]
#  [1 1]
#  [2 2]
#  [8 8]
#  [2 2]
#  [2 2]
#  [9 9]
#  [7 7]
#  [2 2]
#  [3 3]
#  [6 6]
#  [0 0]
#  [5 5]
#  [3 3]
#  [7 7]
#  [5 5]
#  [1 1]
#  [2 2]
#  [9 9]
#  [9 9]
#  [3 3]
#  [1 1]
#  [7 7]
#  [7 7]
#  [4 4]
#  [8 8]
#  [5 5]
#  [8 8]
#  [5 5]
#  [5 5]
#  [2 2]
#  [5 5]
#  [9 9]
#  [0 0]
#  [7 7]
#  [1 1]
#  [4 4]
#  [4 7]
#  [3 3]
# ...

# %%
# Prediction
from sklearn.metrics import accuracy_score
print("Accuracy of the Model:{0}%",format(accuracy_score(y_test, y_pred)*100))
# Out:
# Accuracy of the Model:{0}% 97.11111111111111

# %%
# Comparing accuracy using different methods of SVC
from sklearn import svm
model1=svm.SVC(kernel='linear')
model2=svm.SVC(kernel='rbf')
model3=svm.SVC(gamma=0.001)

model1.fit(x_train, y_train)
model2.fit(x_train, y_train)
model3.fit(x_train, y_train)

y_predModel1= model1.predict(x_test)
y_predModel2= model2.predict(x_test)
y_predModel3= model3.predict(x_test)

print("Accuracy of the Model 1 :{0}%",format(accuracy_score(y_test, y_predModel1)*100))
print("Accuracy of the Model 2 :{0}%",format(accuracy_score(y_test, y_predModel2)*100))
print("Accuracy of the Model 3 :{0}%",format(accuracy_score(y_test, y_predModel3)*100))
# Out:
# Accuracy of the Model 1 :{0}% 97.11111111111111
# Accuracy of the Model 2 :{0}% 99.11111111111111
# Accuracy of the Model 3 :{0}% 99.55555555555556
